# %% [markdown]
# # MODS206 - Data analysis in economics 2 - Applied Econometrics
#
# ### Authors:
# * **João Lucas Furtado Melga**
# * **Leonardo Hannas de Carvalho Santos**
# * **Yuri de Sene Alvizi**

# %% [markdown]
# ---
# ## Imports of the the useful packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
# !pip install arrow
# Out:
# Requirement already satisfied: arrow in /Users/leonardohannas1998/opt/anaconda3/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/leonardohannas1998/opt/anaconda3/lib/python3.9/site-packages (from arrow) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/leonardohannas1998/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.0->arrow) (1.16.0)

# %% [markdown]
# ---
# ## Exploratory data analysis

# %% [markdown]
# We first load the main dataset `traffic`.

# %%
traffic = pd.read_feather('codedDataset/trafficDataset.feather')
traffic
# Out:
#           city  station  weather  dow   datetime  hour  speed  vehicleType  \
# 0            1        1        3    4 2021-04-01     0     31            2
# 1            1        1        3    4 2021-04-01     0     38            2
# 2            1        1        3    4 2021-04-01     0     29            3
# 3            1        1        3    4 2021-04-01     0     42            1
# 4            1        1        3    4 2021-04-01     0     41            2
# ...        ...      ...      ...  ...        ...   ...    ...          ...
# 43952647     6       10        1    6 2021-07-31     0     40            1
# 43952648     6       10        1    6 2021-07-31     0     48            2
# 43952649     6       10        1    6 2021-07-31     0     43            2
# 43952650     6       10        1    6 2021-07-31     0     44            3
# 43952651     6       10        1    6 2021-07-31     0     31            1
#
#           energyConsumption  trafficCongestion  carCrash  pedestrianDeath
# 0                   9.35676                  1     False            False
# 1                   8.35296                  1     False            False
# 2                  11.29870                  1     False            False
# 3                   6.56640                  1     False            False
# 4                   7.99116                  1     False            False
# ...                     ...                ...       ...              ...
# 43952647            6.75600                  3     False            False
# 43952648            7.30656                  3     False            False
# 43952649            7.77276                  3     False            False
# 43952650            8.94880                  3     False            False
# 43952651            7.79730                  3     False            False
#
# [43952652 rows x 12 columns]

# %% [markdown]
# We now extract some useful statistics from the dataset. Namely, the mean and standard deviation, represented by the datasets `df_mean` and `df_std`, respectively.

# %%
df_mean = traffic.groupby('city').mean().drop(columns=['station', 'weather', 'dow', 'vehicleType', 'hour'])
df_mean
# Out:
#           speed  energyConsumption  trafficCongestion  carCrash  \
# city
# 1     33.383528           9.552725           2.948498  0.002468
# 2     39.501495           8.566721           2.975273  0.002963
# 3     39.501675           8.566848           2.471608  0.002382
# 4     39.501333           8.565293           1.180170  0.001197
# 5     39.510016           8.566635           1.000000  0.000999
# 6     39.497612           8.567330           2.917976  0.002884
#
#       pedestrianDeath
# city
# 1            0.000330
# 2            0.000398
# 3            0.000325
# 4            0.000123
# 5            0.000145
# 6            0.000378

# %%
df_std = traffic.groupby('city').std().drop(columns=['station', 'weather', 'dow', 'vehicleType', 'hour'])
df_std
# Out:
#          speed  energyConsumption  trafficCongestion  carCrash  \
# city
# 1     8.901254           2.098720           0.282210  0.049620
# 2     5.007999           1.506273           0.185971  0.054357
# 3     5.008598           1.506875           0.782969  0.048743
# 4     5.009140           1.505781           0.384329  0.034576
# 5     5.007146           1.506842           0.000000  0.031594
# 6     5.008756           1.506719           0.349471  0.053624
#
#       pedestrianDeath
# city
# 1            0.018166
# 2            0.019949
# 3            0.018024
# 4            0.011108
# 5            0.012061
# 6            0.019439

# %% [markdown]
# From the dataframe above, `df_std`, we see that the standard deviation of the speed of the **city 1** is higher. We will investigate it.
#
# To that, we will load another dataset, the `city_info` dataset, shown below.

# %%
city_info = pd.read_csv('info/cityInfo.csv')
city_info.columns = ['city', 'size', 'population', 'popDensity', 'cityName']
city_info
# Out:
#    city  size  population   popDensity     cityName
# 0     1   192      379909  1978.692708  Azzurropoli
# 1     2    91      453991  4988.912088  Biancavilla
# 2     3   363      271008   746.578512   Lavandonia
# 3     4   454      152110   335.044053  Celestopoli
# 4     5   394       52620   133.553299  Plumbeopoli
# 5     6   183      303659  1659.338798  Aranciopoli

# %% [markdown]
# Then, we merge the `df_mean` and the `city_info` datasets into the final dataset `cities`.

# %%
cities = df_mean.merge(city_info, on='city')
cities
# Out:
#    city      speed  energyConsumption  trafficCongestion  carCrash  \
# 0     1  33.383528           9.552725           2.948498  0.002468
# 1     2  39.501495           8.566721           2.975273  0.002963
# 2     3  39.501675           8.566848           2.471608  0.002382
# 3     4  39.501333           8.565293           1.180170  0.001197
# 4     5  39.510016           8.566635           1.000000  0.000999
# 5     6  39.497612           8.567330           2.917976  0.002884
#
#    pedestrianDeath  size  population   popDensity     cityName
# 0         0.000330   192      379909  1978.692708  Azzurropoli
# 1         0.000398    91      453991  4988.912088  Biancavilla
# 2         0.000325   363      271008   746.578512   Lavandonia
# 3         0.000123   454      152110   335.044053  Celestopoli
# 4         0.000145   394       52620   133.553299  Plumbeopoli
# 5         0.000378   183      303659  1659.338798  Aranciopoli

# %% [markdown]
# Now, a *heatmap* of the correlation matrix of the `cities` dataset is shown.

# %%
plt.figure(figsize=(10, 6), dpi=100)
sns.heatmap(cities.corr(), cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# Since that we have constated that the standard deviation of the speed of the **city 1** is higher by checking the `df_std` dataset, we will grab the `traffic` dataset and perform a *groupby* operation, using the *day* as criteria to group the data. Then, we calculate the mean of the resulting data. The final result is stored in the `city_1` dataset.

# %%
city_1 = traffic[traffic['city'] == 1].groupby(pd.Grouper(key='datetime', freq='D')).mean().drop(columns=['city', 'station', 'weather', 'dow', 'vehicleType', 'hour'])
city_1
# Out:
#                 speed  energyConsumption  trafficCongestion  carCrash  \
# datetime
# 2021-04-01  39.502444           8.563826           2.920885  0.002989
# 2021-04-02  39.480170           8.570519           2.920581  0.002975
# 2021-04-03  39.523594           8.556730           3.000000  0.003190
# 2021-04-04  39.476120           8.568096           3.000000  0.003345
# 2021-04-05  39.520970           8.565371           2.930426  0.002663
# ...               ...                ...                ...       ...
# 2021-07-27  27.183649          10.555001           2.922449  0.002161
# 2021-07-28  27.180771          10.558136           2.939915  0.002183
# 2021-07-29  27.214167          10.553890           2.920430  0.001874
# 2021-07-30  27.141938          10.558210           2.930771  0.002036
# 2021-07-31  27.059675          10.608184           3.000000  0.002034
#
#             pedestrianDeath
# datetime
# 2021-04-01         0.000338
# 2021-04-02         0.000489
# 2021-04-03         0.000479
# 2021-04-04         0.000368
# 2021-04-05         0.000334
# ...                     ...
# 2021-07-27         0.000259
# 2021-07-28         0.000258
# 2021-07-29         0.000272
# 2021-07-30         0.000248
# 2021-07-31         0.000678
#
# [122 rows x 5 columns]

# %% [markdown]
# Since we have perceived a clear **change in the parttern of both the speed and the energy consumption values according to the time**, we will plot this data, as well as the car crash data versus the time.

# %%
# City data visualization 
plt.figure(figsize=(10, 6), dpi=100)

# Speed vs Day
g1 = sns.relplot(x='datetime', y='speed', kind='line', data=city_1, height=6, aspect=2, linewidth=3)
g1.figure.autofmt_xdate() 
g1.set_xlabels('Date')
g1.set_ylabels('Speed')
g1.figure.suptitle('Daily Average Speed in City 1', y=1.05)
# g1.figure.suptitle('City 1 Speed Visualization', y=1.05)

# Energy consumption vs Day
g2 = sns.relplot(x='datetime', y='energyConsumption', kind='line', data=city_1, height=6, aspect=2, linewidth=3)
g2.figure.autofmt_xdate()
g2.set_xlabels('Date')
g2.set_ylabels('Energy Consumption')
g2.figure.suptitle('Daily Average Energy Consumption in City 1', y=1.05)
# g2.figure.suptitle('City 1 Energy Consumption Visualization', y=1.05)

# Traffic congestion vs Day
g3 = sns.relplot(x='datetime', y='trafficCongestion', kind='line', data=city_1, height=6, aspect=2, linewidth=3)
g3.figure.autofmt_xdate()
g3.set_xlabels('Date')
g3.set_ylabels('Traffic Congestion')
g3.figure.suptitle('Daily Average Traffic Congestion in City 1', y=1.05)
# g3.figure.suptitle('City 1 Traffic Congestion Visualization', y=1.05)

plt.show()

# %% [markdown]
# Now, we can see how this change of behavior in the **city 1** is represented when we perform an analysis in **each station of this city**. To do this, we will group the data by the *station* and the *day* and calculate the mean of the resulting data. The final result is stored in the `stations_city_1_mean` dataset.

# %%
stations_city_1_mean = traffic[traffic['city'] == 1].groupby(['station', pd.Grouper(key='datetime', freq='D')]).mean().drop(columns=['city', 'weather', 'dow', 'vehicleType', 'hour'])
stations_city_1_mean
# Out:
#                         speed  energyConsumption  trafficCongestion  carCrash  \
# station datetime
# 1       2021-04-01  39.421352           8.586321           2.884873  0.003347
#         2021-04-02  39.434616           8.586430           2.772947  0.002332
#         2021-04-03  39.523284           8.562825           3.000000  0.003175
#         2021-04-04  39.538990           8.565154           3.000000  0.002136
#         2021-04-05  39.525909           8.564945           2.880901  0.003455
# ...                       ...                ...                ...       ...
# 10      2021-07-27  24.478435          10.987449           2.911271  0.002059
#         2021-07-28  24.520537          11.008755           2.912668  0.001830
#         2021-07-29  24.420923          10.987493           2.919844  0.001336
#         2021-07-30  24.469350          10.965828           2.930280  0.002156
#         2021-07-31  24.422000          11.069551           3.000000  0.002000
#
#                     pedestrianDeath
# station datetime
# 1       2021-04-01         0.000335
#         2021-04-02         0.000833
#         2021-04-03         0.000454
#         2021-04-04         0.000610
#         2021-04-05         0.000329
# ...                             ...
# 10      2021-07-27         0.000206
#         2021-07-28         0.000102
#         2021-07-29         0.000308
#         2021-07-30         0.000308
#         2021-07-31         0.000000
#
# [1220 rows x 5 columns]

# %% [markdown]
# We proceed similarly, but now we compute the standard deviation of the resulting data of the city 1. The final result is stored in the `stations_city_1_std` dataset.

# %%
stations_city_1_std =  traffic[traffic['city'] == 1].groupby(['station']).std().drop(columns=['city', 'weather', 'dow', 'vehicleType', 'hour'])
stations_city_1_std
# Out:
#             speed  energyConsumption  trafficCongestion  carCrash  \
# station
# 1        9.003540           2.146350           0.408904  0.048072
# 2        9.001536           2.148230           0.227418  0.048783
# 3        9.007192           2.146495           0.220044  0.049049
# 4        5.006400           1.506766           0.224130  0.053505
# 5        9.008465           2.146914           0.298202  0.048956
# 6        9.005037           2.146676           0.300439  0.047905
# 7        5.004583           1.506096           0.414765  0.053696
# 8        8.997093           2.145184           0.229075  0.048943
# 9        9.009863           2.149017           0.236556  0.048882
# 10       9.004242           2.146101           0.298098  0.048943
#
#          pedestrianDeath
# station
# 1               0.017546
# 2               0.017631
# 3               0.017638
# 4               0.020232
# 5               0.017982
# 6               0.017916
# 7               0.019105
# 8               0.017961
# 9               0.017694
# 10              0.017885

# %% [markdown]
# From the dataset above, `stations_city_1_std`, we see that **the stations 4 and 7 have lower speed standard deviations**. To visualize it, we will plot the values of the mean of the speed in the city 1, for each station, versus the time.

# %%
plt.figure(figsize=(10, 6), dpi=100)

# Average speed vs Day for each station in the city 1
g = sns.FacetGrid(stations_city_1_mean.reset_index(), col="station", col_wrap=3, height=3, aspect=2)
g = g.map(plt.plot, "datetime", "speed", marker=".")

# Rotation of the x-axis labels for better visibility
for ax in g.axes:
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

plt.tight_layout()

# g.figure.suptitle("Average Speed vs Day for all stations in the city 1", size=22)
# g.figure.suptitle("Daily Average Speed per Station in City 1", size=22)
plt.subplots_adjust(top=0.9)

plt.show()

# %% [markdown]
# From the plot above, we see that **only the stations 4 and 7 did not present any significant change in the average speed values** through the days. This justifies their lower values in the standard deviation.

# %% [markdown]
# Now, since we have detected this particular behavior in the city 1, we will perform a macro analysis, considering all the cities. we start by visualizing the average speed by city versus the date.

# %%
cities
# Out:
#    city      speed  energyConsumption  trafficCongestion  carCrash  \
# 0     1  33.383528           9.552725           2.948498  0.002468
# 1     2  39.501495           8.566721           2.975273  0.002963
# 2     3  39.501675           8.566848           2.471608  0.002382
# 3     4  39.501333           8.565293           1.180170  0.001197
# 4     5  39.510016           8.566635           1.000000  0.000999
# 5     6  39.497612           8.567330           2.917976  0.002884
#
#    pedestrianDeath  size  population   popDensity     cityName
# 0         0.000330   192      379909  1978.692708  Azzurropoli
# 1         0.000398    91      453991  4988.912088  Biancavilla
# 2         0.000325   363      271008   746.578512   Lavandonia
# 3         0.000123   454      152110   335.044053  Celestopoli
# 4         0.000145   394       52620   133.553299  Plumbeopoli
# 5         0.000378   183      303659  1659.338798  Aranciopoli

# %%
cities_df = traffic.drop(columns=['station', 'weather', 'dow', 'hour','vehicleType'])
cities_df = cities_df.groupby(['city', pd.Grouper(key='datetime', freq='W')]).mean().reset_index()
cities_df
# Out:
#      city   datetime      speed  energyConsumption  trafficCongestion  \
# 0       1 2021-04-04  39.495906           8.564603           2.963678
# 1       1 2021-04-11  39.503432           8.564683           2.948991
# 2       1 2021-04-18  39.501621           8.564766           2.950327
# 3       1 2021-04-25  39.489103           8.564850           2.952302
# 4       1 2021-05-02  39.498783           8.567746           2.948626
# ..    ...        ...        ...                ...                ...
# 103     6 2021-07-04  39.507829           8.567501           2.920234
# 104     6 2021-07-11  39.500683           8.563735           2.919845
# 105     6 2021-07-18  39.492143           8.566217           2.917698
# 106     6 2021-07-25  39.505150           8.568339           2.920081
# 107     6 2021-08-01  39.491932           8.572040           2.887269
#
#      carCrash  pedestrianDeath
# 0    0.003137         0.000419
# 1    0.002724         0.000380
# 2    0.002897         0.000376
# 3    0.003017         0.000404
# 4    0.002862         0.000386
# ..        ...              ...
# 103  0.002918         0.000391
# 104  0.002839         0.000404
# 105  0.002932         0.000388
# 106  0.002852         0.000376
# 107  0.002849         0.000361
#
# [108 rows x 7 columns]

# %%
speed_cities = cities_df.copy()
plt.figure(figsize=(10, 6), dpi=100)
sns.lineplot(x='datetime', y='speed', hue='city', data=speed_cities, palette='crest')
plt.title("Weekly Average Speed by City")
plt.ylabel("Speed")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Now we investigate the average car crash by city versus the date.

# %%
car_crash_cities = cities_df.copy()

plt.figure(figsize=(10, 6), dpi=100)
sns.lineplot(x='datetime', y='carCrash', hue='city', data=car_crash_cities, palette='crest')
plt.title("Weekly Average Car Crashes by City")
plt.ylabel("Car Crashes")
plt.xlabel("Date")
plt.ylim(0.0005, 0.0035)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Now we compute the average pedestrian deaths by city and date.

# %%
pedestrian_death_cities = cities_df.copy()

# groupby(['city', pd.Grouper(key='datetime', freq='W')]).mean().reset_index()

plt.figure(figsize=(10, 6), dpi=100)
sns.lineplot(x='datetime', y='pedestrianDeath', hue='city', data=pedestrian_death_cities, palette='crest')
# plt.title("Average pedestrian deaths by city and date")
plt.title("Weekly Average Pedestrian Deaths by City")
plt.ylabel("Pedestrian Deaths")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.show()

# %%
energy_consumption_cities = cities_df.copy()

# groupby(['city', pd.Grouper(key='datetime', freq='W')]).mean().reset_index()

plt.figure(figsize=(10, 6), dpi=100)
sns.lineplot(x='datetime', y='energyConsumption', hue='city', data=energy_consumption_cities, palette='crest')
plt.title("Weekly Average Energy Consumption by City")
plt.ylabel("Energy Consumption")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We now analyse the average traffic congestion by city and date.

# %%
traffic_congestion_cities = cities_df.copy()

plt.figure(figsize=(10, 6), dpi=100)
sns.lineplot(x='datetime', y='trafficCongestion', hue='city', data=energy_consumption_cities, palette='crest')
plt.title("Average traffic congestion by city and date")
plt.ylabel("Traffic Congestion")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We end this exploratory analysis by studying the demographic data of the cities. We start by loading the `city_info` dataset.

# %%
city_info_sorted = city_info.sort_values('population', ascending=True)

plt.figure(figsize=(10, 6), dpi=100)
sns.barplot(x='city', y='population', hue='cityName', data=city_info, order=city_info_sorted.city, dodge=False, palette='crest')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Population of each city")
plt.ylabel("Population")
plt.xlabel("City")
plt.show()

# %%
city_info_sorted = city_info.sort_values('size', ascending=True)

plt.figure(figsize=(10, 6), dpi=100)
sns.barplot(x='city', y='size', hue='cityName', data=city_info, order=city_info_sorted.city, dodge=False, palette='crest')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Size of each city")
plt.ylabel("Population")
plt.xlabel("City")
plt.show()

# %%
city_info_sorted = city_info.sort_values('popDensity', ascending=True)

plt.figure(figsize=(10, 6), dpi=100)
sns.barplot(x='city', y='popDensity', hue='cityName', data=city_info, order=city_info_sorted.city, dodge=False, palette='crest')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.title("Population density of each city")
plt.ylabel("Population Density")
plt.xlabel("City")
plt.show()

# %%
city_info
# Out:
#    city  size  population   popDensity     cityName
# 0     1   192      379909  1978.692708  Azzurropoli
# 1     2    91      453991  4988.912088  Biancavilla
# 2     3   363      271008   746.578512   Lavandonia
# 3     4   454      152110   335.044053  Celestopoli
# 4     5   394       52620   133.553299  Plumbeopoli
# 5     6   183      303659  1659.338798  Aranciopoli

# %% [markdown]
# ---
# ## Regression analysis

# %%
city_1
# Out:
#                 speed  energyConsumption  trafficCongestion  carCrash  \
# datetime
# 2021-04-01  39.502444           8.563826           2.920885  0.002989
# 2021-04-02  39.480170           8.570519           2.920581  0.002975
# 2021-04-03  39.523594           8.556730           3.000000  0.003190
# 2021-04-04  39.476120           8.568096           3.000000  0.003345
# 2021-04-05  39.520970           8.565371           2.930426  0.002663
# ...               ...                ...                ...       ...
# 2021-07-27  27.183649          10.555001           2.922449  0.002161
# 2021-07-28  27.180771          10.558136           2.939915  0.002183
# 2021-07-29  27.214167          10.553890           2.920430  0.001874
# 2021-07-30  27.141938          10.558210           2.930771  0.002036
# 2021-07-31  27.059675          10.608184           3.000000  0.002034
#
#             pedestrianDeath
# datetime
# 2021-04-01         0.000338
# 2021-04-02         0.000489
# 2021-04-03         0.000479
# 2021-04-04         0.000368
# 2021-04-05         0.000334
# ...                     ...
# 2021-07-27         0.000259
# 2021-07-28         0.000258
# 2021-07-29         0.000272
# 2021-07-30         0.000248
# 2021-07-31         0.000678
#
# [122 rows x 5 columns]

# %%
stations_city_1 = stations_city_1_mean.reset_index()
stations_city_1
# Out:
#       station   datetime      speed  energyConsumption  trafficCongestion  \
# 0           1 2021-04-01  39.421352           8.586321           2.884873
# 1           1 2021-04-02  39.434616           8.586430           2.772947
# 2           1 2021-04-03  39.523284           8.562825           3.000000
# 3           1 2021-04-04  39.538990           8.565154           3.000000
# 4           1 2021-04-05  39.525909           8.564945           2.880901
# ...       ...        ...        ...                ...                ...
# 1215       10 2021-07-27  24.478435          10.987449           2.911271
# 1216       10 2021-07-28  24.520537          11.008755           2.912668
# 1217       10 2021-07-29  24.420923          10.987493           2.919844
# 1218       10 2021-07-30  24.469350          10.965828           2.930280
# 1219       10 2021-07-31  24.422000          11.069551           3.000000
#
#       carCrash  pedestrianDeath
# 0     0.003347         0.000335
# 1     0.002332         0.000833
# 2     0.003175         0.000454
# 3     0.002136         0.000610
# 4     0.003455         0.000329
# ...        ...              ...
# 1215  0.002059         0.000206
# 1216  0.001830         0.000102
# 1217  0.001336         0.000308
# 1218  0.002156         0.000308
# 1219  0.002000         0.000000
#
# [1220 rows x 7 columns]

# %%
# Stations 4 and 7 of the city 1
unchanged_stations_city_1 = stations_city_1.loc[stations_city_1['station'].isin([4,7])].reset_index(drop=True)
unchanged_stations_city_1
# Out:
#      station   datetime      speed  energyConsumption  trafficCongestion  \
# 0          4 2021-04-01  39.520173           8.570128           2.943457
# 1          4 2021-04-02  39.374095           8.579193           2.952847
# 2          4 2021-04-03  39.530500           8.555673           3.000000
# 3          4 2021-04-04  39.533917           8.558125           3.000000
# 4          4 2021-04-05  39.427184           8.582481           2.969688
# ..       ...        ...        ...                ...                ...
# 239        7 2021-07-27  39.532740           8.545614           2.855237
# 240        7 2021-07-28  39.487380           8.565759           2.881150
# 241        7 2021-07-29  39.474633           8.594355           2.890353
# 242        7 2021-07-30  39.537847           8.519576           2.883743
# 243        7 2021-07-31  39.717472           8.653766           3.000000
#
#      carCrash  pedestrianDeath
# 0    0.002356         0.000196
# 1    0.002837         0.000489
# 2    0.003750         0.000500
# 3    0.004000         0.000500
# 4    0.002040         0.000389
# ..        ...              ...
# 239  0.002607         0.000460
# 240  0.003035         0.000479
# 241  0.003180         0.000303
# 242  0.002555         0.000160
# 243  0.003717         0.000000
#
# [244 rows x 7 columns]

# %%
# Stations 1, 2, 3, 5, 6, 8, 9 and 10 of the city 1
changed_stations_city_1 = stations_city_1.loc[~stations_city_1['station'].isin([4,7])].reset_index(drop=True)
changed_stations_city_1
# Out:
#      station   datetime      speed  energyConsumption  trafficCongestion  \
# 0          1 2021-04-01  39.421352           8.586321           2.884873
# 1          1 2021-04-02  39.434616           8.586430           2.772947
# 2          1 2021-04-03  39.523284           8.562825           3.000000
# 3          1 2021-04-04  39.538990           8.565154           3.000000
# 4          1 2021-04-05  39.525909           8.564945           2.880901
# ..       ...        ...        ...                ...                ...
# 971       10 2021-07-27  24.478435          10.987449           2.911271
# 972       10 2021-07-28  24.520537          11.008755           2.912668
# 973       10 2021-07-29  24.420923          10.987493           2.919844
# 974       10 2021-07-30  24.469350          10.965828           2.930280
# 975       10 2021-07-31  24.422000          11.069551           3.000000
#
#      carCrash  pedestrianDeath
# 0    0.003347         0.000335
# 1    0.002332         0.000833
# 2    0.003175         0.000454
# 3    0.002136         0.000610
# 4    0.003455         0.000329
# ..        ...              ...
# 971  0.002059         0.000206
# 972  0.001830         0.000102
# 973  0.001336         0.000308
# 974  0.002156         0.000308
# 975  0.002000         0.000000
#
# [976 rows x 7 columns]

# %% [markdown]
# ---
# ## Differences-in-Differences

# %%
stations_city_1_mean
# Out:
#                         speed  energyConsumption  trafficCongestion  carCrash  \
# station datetime
# 1       2021-04-01  39.421352           8.586321           2.884873  0.003347
#         2021-04-02  39.434616           8.586430           2.772947  0.002332
#         2021-04-03  39.523284           8.562825           3.000000  0.003175
#         2021-04-04  39.538990           8.565154           3.000000  0.002136
#         2021-04-05  39.525909           8.564945           2.880901  0.003455
# ...                       ...                ...                ...       ...
# 10      2021-07-27  24.478435          10.987449           2.911271  0.002059
#         2021-07-28  24.520537          11.008755           2.912668  0.001830
#         2021-07-29  24.420923          10.987493           2.919844  0.001336
#         2021-07-30  24.469350          10.965828           2.930280  0.002156
#         2021-07-31  24.422000          11.069551           3.000000  0.002000
#
#                     pedestrianDeath
# station datetime
# 1       2021-04-01         0.000335
#         2021-04-02         0.000833
#         2021-04-03         0.000454
#         2021-04-04         0.000610
#         2021-04-05         0.000329
# ...                             ...
# 10      2021-07-27         0.000206
#         2021-07-28         0.000102
#         2021-07-29         0.000308
#         2021-07-30         0.000308
#         2021-07-31         0.000000
#
# [1220 rows x 5 columns]

# %%
stations_city_1
# Out:
#       station   datetime      speed  energyConsumption  trafficCongestion  \
# 0           1 2021-04-01  39.421352           8.586321           2.884873
# 1           1 2021-04-02  39.434616           8.586430           2.772947
# 2           1 2021-04-03  39.523284           8.562825           3.000000
# 3           1 2021-04-04  39.538990           8.565154           3.000000
# 4           1 2021-04-05  39.525909           8.564945           2.880901
# ...       ...        ...        ...                ...                ...
# 1215       10 2021-07-27  24.478435          10.987449           2.911271
# 1216       10 2021-07-28  24.520537          11.008755           2.912668
# 1217       10 2021-07-29  24.420923          10.987493           2.919844
# 1218       10 2021-07-30  24.469350          10.965828           2.930280
# 1219       10 2021-07-31  24.422000          11.069551           3.000000
#
#       carCrash  pedestrianDeath
# 0     0.003347         0.000335
# 1     0.002332         0.000833
# 2     0.003175         0.000454
# 3     0.002136         0.000610
# 4     0.003455         0.000329
# ...        ...              ...
# 1215  0.002059         0.000206
# 1216  0.001830         0.000102
# 1217  0.001336         0.000308
# 1218  0.002156         0.000308
# 1219  0.002000         0.000000
#
# [1220 rows x 7 columns]

# %%
# City 1

# Control Group (station 4)
control_group = stations_city_1[stations_city_1['station'].isin([4, 7])].reset_index().drop(columns=['index'])

# Treatment Group (station 1)
treatment_group = stations_city_1[~stations_city_1['station'].isin([4, 7])].reset_index().drop(columns=['index'])

# %%
control_group
# Out:
#      station   datetime      speed  energyConsumption  trafficCongestion  \
# 0          4 2021-04-01  39.520173           8.570128           2.943457
# 1          4 2021-04-02  39.374095           8.579193           2.952847
# 2          4 2021-04-03  39.530500           8.555673           3.000000
# 3          4 2021-04-04  39.533917           8.558125           3.000000
# 4          4 2021-04-05  39.427184           8.582481           2.969688
# ..       ...        ...        ...                ...                ...
# 239        7 2021-07-27  39.532740           8.545614           2.855237
# 240        7 2021-07-28  39.487380           8.565759           2.881150
# 241        7 2021-07-29  39.474633           8.594355           2.890353
# 242        7 2021-07-30  39.537847           8.519576           2.883743
# 243        7 2021-07-31  39.717472           8.653766           3.000000
#
#      carCrash  pedestrianDeath
# 0    0.002356         0.000196
# 1    0.002837         0.000489
# 2    0.003750         0.000500
# 3    0.004000         0.000500
# 4    0.002040         0.000389
# ..        ...              ...
# 239  0.002607         0.000460
# 240  0.003035         0.000479
# 241  0.003180         0.000303
# 242  0.002555         0.000160
# 243  0.003717         0.000000
#
# [244 rows x 7 columns]

# %%
treatment_group
# Out:
#      station   datetime      speed  energyConsumption  trafficCongestion  \
# 0          1 2021-04-01  39.421352           8.586321           2.884873
# 1          1 2021-04-02  39.434616           8.586430           2.772947
# 2          1 2021-04-03  39.523284           8.562825           3.000000
# 3          1 2021-04-04  39.538990           8.565154           3.000000
# 4          1 2021-04-05  39.525909           8.564945           2.880901
# ..       ...        ...        ...                ...                ...
# 971       10 2021-07-27  24.478435          10.987449           2.911271
# 972       10 2021-07-28  24.520537          11.008755           2.912668
# 973       10 2021-07-29  24.420923          10.987493           2.919844
# 974       10 2021-07-30  24.469350          10.965828           2.930280
# 975       10 2021-07-31  24.422000          11.069551           3.000000
#
#      carCrash  pedestrianDeath
# 0    0.003347         0.000335
# 1    0.002332         0.000833
# 2    0.003175         0.000454
# 3    0.002136         0.000610
# 4    0.003455         0.000329
# ..        ...              ...
# 971  0.002059         0.000206
# 972  0.001830         0.000102
# 973  0.001336         0.000308
# 974  0.002156         0.000308
# 975  0.002000         0.000000
#
# [976 rows x 7 columns]

# %%
control_group['treatment'] = 0
treatment_group['treatment'] = 1

# %%
diff_in_diff = control_group.copy()
diff_in_diff = pd.concat([diff_in_diff, treatment_group]).reset_index().drop(columns=['index'])

diff_in_diff
# Out:
#       station   datetime      speed  energyConsumption  trafficCongestion  \
# 0           4 2021-04-01  39.520173           8.570128           2.943457
# 1           4 2021-04-02  39.374095           8.579193           2.952847
# 2           4 2021-04-03  39.530500           8.555673           3.000000
# 3           4 2021-04-04  39.533917           8.558125           3.000000
# 4           4 2021-04-05  39.427184           8.582481           2.969688
# ...       ...        ...        ...                ...                ...
# 1215       10 2021-07-27  24.478435          10.987449           2.911271
# 1216       10 2021-07-28  24.520537          11.008755           2.912668
# 1217       10 2021-07-29  24.420923          10.987493           2.919844
# 1218       10 2021-07-30  24.469350          10.965828           2.930280
# 1219       10 2021-07-31  24.422000          11.069551           3.000000
#
#       carCrash  pedestrianDeath  treatment
# 0     0.002356         0.000196          0
# 1     0.002837         0.000489          0
# 2     0.003750         0.000500          0
# 3     0.004000         0.000500          0
# 4     0.002040         0.000389          0
# ...        ...              ...        ...
# 1215  0.002059         0.000206          1
# 1216  0.001830         0.000102          1
# 1217  0.001336         0.000308          1
# 1218  0.002156         0.000308          1
# 1219  0.002000         0.000000          1
#
# [1220 rows x 8 columns]

# %%
diff_in_diff['post'] = (diff_in_diff['datetime'] >= '2021-06-01').astype(int)
# diff_in_diff['interaction'] = diff_in_diff['treatment'] * diff_in_diff['post']
diff_in_diff
# Out:
#       station   datetime      speed  energyConsumption  trafficCongestion  \
# 0           4 2021-04-01  39.520173           8.570128           2.943457
# 1           4 2021-04-02  39.374095           8.579193           2.952847
# 2           4 2021-04-03  39.530500           8.555673           3.000000
# 3           4 2021-04-04  39.533917           8.558125           3.000000
# 4           4 2021-04-05  39.427184           8.582481           2.969688
# ...       ...        ...        ...                ...                ...
# 1215       10 2021-07-27  24.478435          10.987449           2.911271
# 1216       10 2021-07-28  24.520537          11.008755           2.912668
# 1217       10 2021-07-29  24.420923          10.987493           2.919844
# 1218       10 2021-07-30  24.469350          10.965828           2.930280
# 1219       10 2021-07-31  24.422000          11.069551           3.000000
#
#       carCrash  pedestrianDeath  treatment  post
# 0     0.002356         0.000196          0     0
# 1     0.002837         0.000489          0     0
# 2     0.003750         0.000500          0     0
# 3     0.004000         0.000500          0     0
# 4     0.002040         0.000389          0     0
# ...        ...              ...        ...   ...
# 1215  0.002059         0.000206          1     1
# 1216  0.001830         0.000102          1     1
# 1217  0.001336         0.000308          1     1
# 1218  0.002156         0.000308          1     1
# 1219  0.002000         0.000000          1     1
#
# [1220 rows x 9 columns]

# %% [markdown]
# ---
# Correction Luca:

# %%
diff_in_diff['day'] = (diff_in_diff['datetime'] - pd.to_datetime('2021-06-01')).dt.days 

diff_in_diff['interaction'] = diff_in_diff['treatment'] * diff_in_diff['day']

diff_in_diff
# Out:
#       station   datetime      speed  energyConsumption  trafficCongestion  \
# 0           4 2021-04-01  39.520173           8.570128           2.943457
# 1           4 2021-04-02  39.374095           8.579193           2.952847
# 2           4 2021-04-03  39.530500           8.555673           3.000000
# 3           4 2021-04-04  39.533917           8.558125           3.000000
# 4           4 2021-04-05  39.427184           8.582481           2.969688
# ...       ...        ...        ...                ...                ...
# 1215       10 2021-07-27  24.478435          10.987449           2.911271
# 1216       10 2021-07-28  24.520537          11.008755           2.912668
# 1217       10 2021-07-29  24.420923          10.987493           2.919844
# 1218       10 2021-07-30  24.469350          10.965828           2.930280
# 1219       10 2021-07-31  24.422000          11.069551           3.000000
#
#       carCrash  pedestrianDeath  treatment  post  day  interaction
# 0     0.002356         0.000196          0     0  -61            0
# 1     0.002837         0.000489          0     0  -60            0
# 2     0.003750         0.000500          0     0  -59            0
# 3     0.004000         0.000500          0     0  -58            0
# 4     0.002040         0.000389          0     0  -57            0
# ...        ...              ...        ...   ...  ...          ...
# 1215  0.002059         0.000206          1     1   56           56
# 1216  0.001830         0.000102          1     1   57           57
# 1217  0.001336         0.000308          1     1   58           58
# 1218  0.002156         0.000308          1     1   59           59
# 1219  0.002000         0.000000          1     1   60           60
#
# [1220 rows x 11 columns]

# %%
regression_coeffs = []
coefficients_std = []

# Loop over each week and run the regression
for day in range(min(diff_in_diff['day']), max(diff_in_diff['day']) + 1):
    
    diff_in_diff_day = diff_in_diff[diff_in_diff['day'] == day]
    
    model = smf.ols(formula='pedestrianDeath ~ treatment * day', data=diff_in_diff_day).fit()
    
    regression_coeffs.append(model.params)
    coefficients_std.append(model.bse)

# Convert lists of series to a DataFrame
coefficients_df = pd.DataFrame(regression_coeffs)
coefficients_std_df = pd.DataFrame(coefficients_std)

# Add 'week' to the DataFrames
coefficients_df['day'] = range(min(diff_in_diff['day']), max(diff_in_diff['day']) + 1)
coefficients_std_df['day'] = range(min(diff_in_diff['day']), max(diff_in_diff['day']) + 1)

plt.figure(figsize=(10, 6), dpi=100)
plt.errorbar(coefficients_df['day'], coefficients_df['treatment:day'],
             yerr=coefficients_std_df['treatment:day'], fmt='o', ecolor='g', capthick=2)
plt.xlabel('Day')
plt.ylabel('Interaction Coefficient')
plt.title('Interaction Coefficient by Day')
plt.show()

# %%
df = pd.read_feather("codedDataset/trafficDataset.feather")
# Out:
#       city  station   datetime   weather  dow       hour      speed  \
# 0        1        1 2021-04-01  2.264056  4.0  13.957664  39.421352
# 1        1        1 2021-04-02  2.380476  5.0  12.697818  39.434616
# 2        1        1 2021-04-03  1.749168  6.0  11.838524  39.523284
# 3        1        1 2021-04-04  2.144361  7.0  11.329315  39.538990
# 4        1        1 2021-04-05  2.144267  1.0  13.409771  39.525909
# ...    ...      ...        ...       ...  ...        ...        ...
# 7315     6       10 2021-07-27  2.022469  2.0  13.572640  39.536843
# 7316     6       10 2021-07-28  2.120447  3.0  13.477884  39.449371
# 7317     6       10 2021-07-29  1.940046  4.0  13.951536  39.390216
# 7318     6       10 2021-07-30  1.987255  5.0  13.690569  39.480106
# 7319     6       10 2021-07-31  1.000000  6.0   0.000000  39.515789
#
#       vehicleType  energyConsumption  trafficCongestion  carCrash  \
# 0        2.255187           8.586321           2.884873  0.003347
# 1        2.258038           8.586430           2.772947  0.002332
# 2        2.250378           8.562825           3.000000  0.003175
# 3        2.251946           8.565154           3.000000  0.002136
# 4        2.249219           8.564945           2.880901  0.003455
# ...           ...                ...                ...       ...
# 7315     2.269633           8.589141           2.902412  0.002864
# 7316     2.257047           8.584405           2.891912  0.002168
# 7317     2.252446           8.583760           2.897611  0.003527
# 7318     2.255791           8.576417           2.892829  0.003546
# 7319     2.315789           8.664480           3.000000  0.005263
#
#       pedestrianDeath
# 0            0.000335
# 1            0.000833
# 2            0.000454
# 3            0.000610
# 4            0.000329
# ...               ...
# 7315         0.000220
# 7316         0.000650
# 7317         0.000114
# 7318         0.000111
# 7319         0.000000
#
# [7320 rows x 12 columns]

# %%
df = df.groupby(['city','station', pd.Grouper(key='datetime', freq='W')]).mean().reset_index()
df.to_csv('info/weeklyGrouping.csv')
